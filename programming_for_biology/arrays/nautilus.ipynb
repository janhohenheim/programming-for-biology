# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

t = np.linspace(0, 4, 1000)
gamma = 1.47
x = gamma**(4 * t)*np.cos(2 * np.pi * t)
y = gamma**(4 * t)*np.sin(2 * np.pi * t)

plt.title("Nautilus shell")
plt.plot(x, y)
plt.show()

print("Leftmost point: ", min(x))
# Out:
# Leftmost point:  -226.65373282444577
